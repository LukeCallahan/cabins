# %%
import pandas as pd

# %%
cedar = {
    2.5: [22, 14],
    1: [
        6, 6, 6, 8, 8, 7,
        6, 10, 6, 5, 10, 10, 10,
        8, 8, 9, 9, 8, 6, 6, 
        9, 9, 9, 9, 9, 7, 8, 8,
        11, 11, 11, 11, 11, 5, 5, 8, 5,
        8, 9, 8, 8, 6, 6, 6, 10,
        6, 7, 9, 10, 12, 13, 14, 14,
        6, 6, 9, 6, 10, 10, 10, 10,
        13, 13, 14, 14, 14, 14, 
        14, 14, 14, 14, 12, 13, 
        15, 15, 15, 15, 15,
        11, 11, 11, 15, 15, 15, 
        11, 11, 11, 11, 11, 11, 11, 
        11, 11, 11, 11, 11, 11, 11,
        5, 7, 13, 14, 12, 12, 12, 
        14, 14, 14, 14, 14, 
        18, 18, 18, 18,  
    ]}
fir = {
    2.5: [18, 13],
    2: [16, 14, 
        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 
        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
        12, 12, 12, 12, 12, 12, 
        12, 12, 12, 12, 12, 12, 
        12, 12, 12, 12, 12, 12, 
        12, 12, 12, 12, 12, 12, 
        12, 12, 12, 12, 12, 12, 
        12, 12, 12, 12, 12, 12, 
        10, 10, 12, 10, 12, 12, 12,
        10, 12, 10, 10, 10, 10, 10, 12, 10        
    ], 
    
    1: [19, 19, 19, 19,
        19, 19, 19, 19, 
        19, 19, 19, 19, 
        19, 19, 19, 19,  
    ]
}
